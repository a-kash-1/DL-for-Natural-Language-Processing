# %%
from textblob import TextBlob
import requests

response = requests.get('https://en.wikipedia.org/w/api.php', params = {'action': 'query','format': 'json','titles': 'Bla Bla Bla','prop': 'extracts','explaintext': True,}).json
page = next(iter(response['query']['pages'].values()))

type(page)
#Raga = open(page['extract'])
#blob = TextBlob(text)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# c:\users\akash.sharma\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     593             if is_new_proxy_conn:
# --> 594                 self._prepare_proxy(conn)
#     595
#
# c:\users\akash.sharma\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     804         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 805         conn.connect()
#     806
#
# c:\users\akash.sharma\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# ...

# %%
blob.noun_phrases

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.06373106060606061, subjectivity=0.43387784090909093)

# %%
words = blob.words
sens = blob.sentences

# %%
type(sens)
polarity_curve_y = [sens[i].sentiment.polarity for i in range(len(sens))]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(polarity_curve_y)
plt.show()
